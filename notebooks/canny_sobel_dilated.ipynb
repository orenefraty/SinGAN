# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi
from skimage import feature,filters
from skimage.color import rgb2gray
from skimage.morphology import dilation,disk

# %%
color = imageio.imread("/Users/orene/work/SinGAN/Input/Paint/amsterdam.jpg")
plt.imshow(color)
plt.show()

# %%
#imageio.imwrite("content_edge.jpg", edges)
#stacked_img = np.stack((gray,)*3, axis=-1)
#imageio.imwrite("content_edge_stacked.jpg", stacked_img)

# %%
grayscale = rgb2gray(img)
    
plt.imshow(grayscale,cmap='gray')

plt.show()

# %%
sobel = filters.sobel(gray)
plt.imshow(sobel,cmap='gray')
plt.show()

# %%
radius = 3
mask = disk(radius)
dilated = dilation(sobel, selem=mask)

plt.imshow(dilated,cmap='gray')

# %%
edges = feature.canny(sobel)
plt.imshow(edges,cmap='gray')

# %%
radius = 3
mask = disk(radius)
dilated = dilation(edges, selem=mask)

plt.imshow(dilated,cmap='gray')

# %%
radius = 6
mask = disk(radius)
dilated = dilation(edges, selem=mask)

plt.imshow(dilated,cmap='gray')

# %%
radius = 1
mask = disk(radius)
dilated = dilation(edges, selem=mask)

plt.imshow(dilated,cmap='gray')
